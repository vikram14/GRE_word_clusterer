# %%
import spacy
import pandas as pd
import numpy as np
from sklearn import manifold
import matplotlib.pyplot as plt

# %%
model=spacy.load('en_core_web_md') # loading pre-trained 300-dimensional word-vectors

# %%
gre_words=df = pd.read_excel('GRE_WORDS.xlsx') # Load the GRE words to cluster

# %%
gre_words['Words']
# Out:
# 0            abound
# 1         amorphous
# 2           austere
# 3             belie
# 4        capricious
# 5          cerebral
# 6         congenial
# 7       conspicuous
# 8           cursory
# 9          daunting
# 10            deify
# 11         didactic
# 12      disseminate
# 13         feasible
# 14            flout
# 15      homogeneous
# 16          humdrum
# 17          insipid
# 18       loquacious
# 19     misanthropic
# 20         misnomer
# 21        negligent
# 22       obsequious
# 23          placate
# 24       proclivity
# 25          puerile
# 26         quixotic
# 27      spendthrift
# 28         taciturn
# 29             wary
#            ...
# 818         abreast
# 819        confound
# 820      digression
# 821     discrepancy
# 822     duplicitous
# 823       expedient
# 824       fabricate
# 825            glum
# 826       harbinger
# 827       intrinsic
# 828        largesse
# 829       libertine
# 830     malfeasance
# 831        manifest
# 832          minute
# 833          modish
# 834         nascent
# 835       perennial
# 836          pious
# 837    providential
# 838         prowess
# 839          schism
# 840         slander
# 841        stalwart
# 842      supplicate
# 843           terse
# 844          tirade
# 845       universal
# 846        vanquish
# 847          woeful
# Name: Words, Length: 848, dtype: object

# %%
# Initialize Embedding array of shape 848x300
num_rows=gre_words['Words'].shape[0]
num_cols=300 # word embedding size
Embeddings= np.empty((num_rows,num_cols))

# %%
def obtain_word_embeds(words,spacy_model, embeds):
    for i in range(words.shape[0]):
        embeds[i,:]=model(words['Words'][i]).vector.reshape(1,300)
    return embeds

# %%
Embeddings=obtain_word_embeds(gre_words, model, Embeddings)

# %%
t_SNE=manifold.TSNE()
visualize_words=t_SNE.fit_transform(Embeddings)

# %%
indices= np.random.choice(848,300)
vis=visualize_words[indices,:]

# %%
# before similarity clustering
ax = plt.axes()
x_data=vis[:,0]
y_data=vis[:,1]
ax.scatter(x_data, y_data, c=y_data)

# %%
def get_cosine_similarity(U):
    row_norm=np.linalg.norm(U,axis=1,keepdims=True)+10**-16
    U_norm= U/row_norm
    similarity_matrix= np.matmul(U_norm,U_norm.T)
    return similarity_matrix

# %%
similarity= get_cosine_similarity(Embeddings)

# %%
def get_similar_vectors(sim, thresh=0.8):
    synonyms={}
    syn_index={}
    for i in range(sim.shape[0]):
        ls=[]
        ls2=[]
        for j in range(i,sim.shape[0]):
            if(sim[i,j]>=thresh):
                ls.append(gre_words['Words'][j])
                ls2.append(j)
        synonyms[gre_words['Words'][i]]=ls
        syn_index[i]=ls2
    return synonyms, syn_index

# %%
syn,idx= get_similar_vectors(similarity)

# %%
plot_idx=[]
for x,y in idx.items():
    if len(y)<=1:
        continue
    else:
        plot_idx.append(y)

# %%
plot_idx_flat=list(set([e for k in plot_idx for e in k ]))
vis=visualize_words[plot_idx_flat,:]
len(plot_idx_flat)
# Out:
# 403

# %%
i=0
for l in plot_idx:
    if len(l)>1:
        print("Cluster"+str(i)+":")
        print(gre_words['Words'][l])
    i+=1
    print()
# Out:
# Cluster0:
# 4      capricious
# 533        fickle
# Name: Words, dtype: object
#
# Cluster1:
# 6       congenial
# 544     conducive
# 572    salubrious
# Name: Words, dtype: object
#
# Cluster2:
# 10           deify
# 90      adulterate
# 105      castigate
# 193       canonize
# 317         deride
# 356         berate
# 361        subsume
# 386    marginalize
# 393     stigmatize
# 439       harangue
# 503        lionize
# 563         malign
# 593         impugn
# 606        upbraid
# 669       lambaste
# 680      excoriate
# 726     deprecate
# 795      exculpate
# Name: Words, dtype: object
#
# Cluster3:
# 11     didactic
# 529    treatise
# Name: Words, dtype: object
#
# Cluster4:
# 13    feasible
# 96    amenable
# Name: Words, dtype: object
#
# Cluster5:
# 14          flout
# 341    contravene
# Name: Words, dtype: object
#
# Cluster6:
# 16       humdrum
# 285    ephemeral
# 389      prosaic
# 621      mundane
# Name: Words, dtype: object
#
# Cluster7:
# 17        insipid
# 100         banal
# 637         vapid
# 744    hodgepodge
# Name: Words, dtype: object
#
# Cluster8:
# 18        loquacious
# 119        ingenuous
# 381      impertinent
# 645           blithe
# 679    imperturbable
# 741       felicitous
# 769        facetious
# Name: Words, dtype: object
#
# Cluster9:
# 19     misanthropic
# 464    chauvinistic
# Name: Words, dtype: object
#
# Cluster10:
# 21     negligent
# 205    dilatory
# Name: Words, dtype: object
#
# Cluster11:
# 22     obsequious
# 252          glib
# 541     officious
# 804    nonchalant
# Name: Words, dtype: object
#
# Cluster12:
# 23      placate
# 188    assuage
# 266     mollify
# 548     appease
# Name: Words, dtype: object
#
# Cluster13:
# 24     proclivity
# 167    propensity
# Name: Words, dtype: object
#
# Cluster14:
# 26     quixotic
# 225      futile
# Name: Words, dtype: object
#
# Cluster15:
# 29            wary
# 302        prudent
# 690          chary
# 730    circumspect
# Name: Words, dtype: object
#
# Cluster16:
# 30      abhor
# 562    loathe
# 792    eschew
# Name: Words, dtype: object
#
# Cluster17:
# 32        chivalrous
# 211       altruistic
# 556    indefatigable
# Name: Words, dtype: object
#
# Cluster18:
# 33     churlish
# 457    captious
# Name: Words, dtype: object
#
# Cluster19:
# 35     complacent
# 166    phlegmatic
# 228     lethargic
# 532        morose
# 557      indolent
# 813     somnolent
# Name: Words, dtype: object
#
# Cluster20:
# 36     cumbersome
# 150    cumbersome
# Name: Words, dtype: object
#
# Cluster21:
# 39          droll
# 147        urbane
# 561    irreverent
# 600         pithy
# 738       erudite
# 750       mordant
# Name: Words, dtype: object
#
# Cluster22:
# 40         eccentric
# 445        whimsical
# 535         eclectic
# 537    idiosyncratic
# 753           quirky
# Name: Words, dtype: object
#
# Cluster23:
# 42     limpid
# 416     lucid
# Name: Words, dtype: object
#
# Cluster24:
# 43        mawkish
# 518    lugubrious
# 673    peccadillo
# Name: Words, dtype: object
#
# Cluster25:
# 47     perfunctory
# 203     desultory
# Name: Words, dtype: object
#
# Cluster26:
# 51     predilection
# 644         aversion
# Name: Words, dtype: object
#
# Cluster27:
# 52       rapacious
# 99      avaricious
# 597        miserly
# 640    acquisitive
# Name: Words, dtype: object
#
# Cluster28:
# 54     satirical
# 237     scathing
# 547      lampoon
# Name: Words, dtype: object
#
# Cluster29:
# 55         sham
# 477    spurious
# 581       bogus
# Name: Words, dtype: object
#
# Cluster30:
# 57     sluggish
# 605       tepid
# Name: Words, dtype: object
#
# Cluster31:
# 59        truculent
# 120    acrimonious
# 121     belligerent
# 215    conciliatory
# 498    iconoclastic
# 630      pugnacious
# Name: Words, dtype: object
#
# Cluster32:
# 62     animosity
# 183    antipathy
# 311        animus
# 497        fester
# 715        enmity
# Name: Words, dtype: object
#
# Cluster33:
# 65     cathartic
# 155     euphoric
# 575    soporific
# 696        heady
# Name: Words, dtype: object
#
# Cluster34:
# 69       eloquent
# 454    articulate
# Name: Words, dtype: object
#
# Cluster35:
# 70     enthrall
# 407     enchant
# Name: Words, dtype: object
#
# Cluster36:
# 73    fortitude
# 89        valor
# Name: Words, dtype: object
#
# Cluster37:
# 75         goad
# 168      foment
# 470    engender
# 717     agitate
# 737      elicit
# Name: Words, dtype: object
#
# Cluster38:
# 77     incontrovertible
# 433          conclusive
# Name: Words, dtype: object
#
# Cluster39:
# 78     itinerant
# 647       dawdle
# Name: Words, dtype: object
#
# Cluster40:
# 79      magnanimous
# 122      beneficent
# 354      benevolent
# 776      munificent
# 837    providential
# Name: Words, dtype: object
#
# Cluster41:
# 90      adulterate
# 105      castigate
# 193       canonize
# 317         deride
# 356         berate
# 361        subsume
# 386    marginalize
# 393     stigmatize
# 439       harangue
# 503        lionize
# 563         malign
# 593         impugn
# 606        upbraid
# 669       lambaste
# 680      excoriate
# 726     deprecate
# 795      exculpate
# Name: Words, dtype: object
#
# Cluster42:
# 92      aggrandize
# 169      embellish
# 404        distort
# 781    prevaricate
# Name: Words, dtype: object
#
# Cluster43:
# 95     ameliorate
# 129    exacerbate
# 461     alleviate
# Name: Words, dtype: object
#
# Cluster44:
# 97     anachronistic
# 550          archaic
# Name: Words, dtype: object
#
# Cluster45:
# 99      avaricious
# 597        miserly
# 640    acquisitive
# Name: Words, dtype: object
#
# Cluster46:
# 100         banal
# 637         vapid
# 744    hodgepodge
# Name: Words, dtype: object
#
# Cluster47:
# 103    calumny
# 840    slander
# Name: Words, dtype: object
#
# Cluster48:
# 104       candid
# 290    intimate
# 319     discreet
# Name: Words, dtype: object
#
# Cluster49:
# 105      castigate
# 193       canonize
# 317         deride
# 356         berate
# 361        subsume
# 386    marginalize
# 393     stigmatize
# 439       harangue
# 503        lionize
# 563         malign
# 593         impugn
# 606        upbraid
# 669       lambaste
# 680      excoriate
# 726     deprecate
# 795      exculpate
# Name: Words, dtype: object
#
# Cluster50:
# 106    caustic
# 135    laconic
# Name: Words, dtype: object
#
# Cluster51:
# 107        construe
# 140    parsimonious
# 153     extrapolate
# 790         ascribe
# Name: Words, dtype: object
#
# Cluster52:
# 109    convoluted
# 213     byzantine
# 481      tortuous
# Name: Words, dtype: object
#
# Cluster53:
# 110      covet
# 280    cherish
# Name: Words, dtype: object
#
# Cluster54:
# 112      decorum
# 418    propriety
# 474      probity
# Name: Words, dtype: object
#
# Cluster55:
# 117    diatribe
# 844      tirade
# Name: Words, dtype: object
#
# Cluster56:
# 118    incredulous
# 492    crestfallen
# Name: Words, dtype: object
#
# Cluster57:
# 119        ingenuous
# 381      impertinent
# 645           blithe
# 679    imperturbable
# 741       felicitous
# 769        facetious
# Name: Words, dtype: object
#
# Cluster58:
# 120    acrimonious
# 121     belligerent
# 215    conciliatory
# 498    iconoclastic
# 630      pugnacious
# Name: Words, dtype: object
#
# Cluster59:
# 121     belligerent
# 215    conciliatory
# 498    iconoclastic
# 630      pugnacious
# Name: Words, dtype: object
#
# Cluster60:
# 122      beneficent
# 354      benevolent
# 776      munificent
# 837    providential
# Name: Words, dtype: object
#
# Cluster61:
# 128    encyclopedic
# 843            terse
# Name: Words, dtype: object
#
# Cluster62:
# 129    exacerbate
# 461     alleviate
# Name: Words, dtype: object
#
# Cluster63:
# 132    hackneyed
# 567    platitude
# Name: Words, dtype: object
#
# Cluster64:
# 139    opprobrium
# 194       censure
# 570      reproach
# Name: Words, dtype: object
#
# Cluster65:
# 140    parsimonious
# 153     extrapolate
# 790         ascribe
# Name: Words, dtype: object
#
# Cluster66:
# 143     renounce
# 181       abjure
# 274        decry
# 350     denounce
# 458     admonish
# 754    repudiate
# Name: Words, dtype: object
#
# Cluster67:
# 145       tenable
# 553    explicable
# Name: Words, dtype: object
#
# Cluster68:
# 147        urbane
# 561    irreverent
# 600         pithy
# 738       erudite
# 750       mordant
# Name: Words, dtype: object
#
# Cluster69:
# 149      vitiate
# 815    supersede
# Name: Words, dtype: object
#
# Cluster70:
# 153    extrapolate
# 790        ascribe
# Name: Words, dtype: object
#
# Cluster71:
# 155     euphoric
# 575    soporific
# 696        heady
# Name: Words, dtype: object
#
# Cluster72:
# 158    fervent
# 397    zealous
# 539     ardent
# 836     pious
# Name: Words, dtype: object
#
# Cluster73:
# 161    painstaking
# 221     exhaustive
# 515       thorough
# 749     meticulous
# Name: Words, dtype: object
#
# Cluster74:
# 165    implicit
# 526       tacit
# Name: Words, dtype: object
#
# Cluster75:
# 166    phlegmatic
# 228     lethargic
# 532        morose
# 557      indolent
# 813     somnolent
# Name: Words, dtype: object
#
# Cluster76:
# 168      foment
# 470    engender
# 717     agitate
# 737      elicit
# Name: Words, dtype: object
#
# Cluster77:
# 169      embellish
# 404        distort
# 781    prevaricate
# Name: Words, dtype: object
#
# Cluster78:
# 170    inviolate
# 555    immutable
# 770     fallible
# Name: Words, dtype: object
#
# Cluster79:
# 172    arresting
# 240    arresting
# Name: Words, dtype: object
#
# Cluster80:
# 173     obstinate
# 241     obstinate
# 270    headstrong
# Name: Words, dtype: object
#
# Cluster81:
# 174    vivacious
# 242    vivacious
# Name: Words, dtype: object
#
# Cluster82:
# 175    histrionic
# 243    histrionic
# Name: Words, dtype: object
#
# Cluster83:
# 176    prodigious
# 244    prodigious
# 667     veritable
# Name: Words, dtype: object
#
# Cluster84:
# 177    tentative
# 245    tentative
# Name: Words, dtype: object
#
# Cluster85:
# 178    falter
# 246    falter
# Name: Words, dtype: object
#
# Cluster86:
# 179    chastise
# 247    chastise
# Name: Words, dtype: object
#
# Cluster87:
# 180        abate
# 642    attenuate
# 817         wane
# Name: Words, dtype: object
#
# Cluster88:
# 181       abjure
# 274        decry
# 350     denounce
# 458     admonish
# 754    repudiate
# Name: Words, dtype: object
#
# Cluster89:
# 183    antipathy
# 311        animus
# 497        fester
# 715        enmity
# Name: Words, dtype: object
#
# Cluster90:
# 184       arcane
# 304    recondite
# Name: Words, dtype: object
#
# Cluster91:
# 186    artless
# 772      gawky
# Name: Words, dtype: object
#
# Cluster92:
# 188    assuage
# 266     mollify
# 548     appease
# Name: Words, dtype: object
#
# Cluster93:
# 189      betray
# 444    conspire
# Name: Words, dtype: object
#
# Cluster94:
# 192    cacophonous
# 743       haphazard
# 757       turbulent
# Name: Words, dtype: object
#
# Cluster95:
# 193       canonize
# 317         deride
# 356         berate
# 361        subsume
# 386    marginalize
# 393     stigmatize
# 439       harangue
# 503        lionize
# 563         malign
# 593         impugn
# 606        upbraid
# 669       lambaste
# 680      excoriate
# 726     deprecate
# 795      exculpate
# Name: Words, dtype: object
#
# Cluster96:
# 194     censure
# 570    reproach
# Name: Words, dtype: object
#
# Cluster97:
# 195      chicanery
# 634    skullduggery
# Name: Words, dtype: object
#
# Cluster98:
# 202    deference
# 646     contempt
# Name: Words, dtype: object
#
# Cluster99:
# 204     diffident
# 383    irresolute
# 480      timorous
# 512      skittish
# Name: Words, dtype: object
#
# Cluster100:
# 206     equivocate
# 430    disentangle
# Name: Words, dtype: object
#
# Cluster101:
# 207    polarize
# 648     deflect
# Name: Words, dtype: object
#
# Cluster102:
# 209     verbose
# 296    pedantic
# 663      prolix
# Name: Words, dtype: object
#
# Cluster103:
# 211       altruistic
# 556    indefatigable
# Name: Words, dtype: object
#
# Cluster104:
# 213    byzantine
# 481     tortuous
# Name: Words, dtype: object
#
# Cluster105:
# 215    conciliatory
# 498    iconoclastic
# 630      pugnacious
# Name: Words, dtype: object
#
# Cluster106:
# 221    exhaustive
# 515      thorough
# 749    meticulous
# Name: Words, dtype: object
#
# Cluster107:
# 223     extraneous
# 513    superfluous
# Name: Words, dtype: object
#
# Cluster108:
# 228    lethargic
# 532       morose
# 557     indolent
# 813    somnolent
# Name: Words, dtype: object
#
# Cluster109:
# 229    metaphorical
# 531      figurative
# Name: Words, dtype: object
#
# Cluster110:
# 235    perpetuate
# 250     propagate
# Name: Words, dtype: object
#
# Cluster111:
# 237    scathing
# 547     lampoon
# Name: Words, dtype: object
#
# Cluster112:
# 241     obstinate
# 270    headstrong
# Name: Words, dtype: object
#
# Cluster113:
# 244    prodigious
# 667     veritable
# Name: Words, dtype: object
#
# Cluster114:
# 251    allusive
# 771      florid
# Name: Words, dtype: object
#
# Cluster115:
# 252          glib
# 541     officious
# 804    nonchalant
# Name: Words, dtype: object
#
# Cluster116:
# 256       astute
# 334    trenchant
# 568    prescient
# Name: Words, dtype: object
#
# Cluster117:
# 259    repercussion
# 534    ramification
# Name: Words, dtype: object
#
# Cluster118:
# 261          refute
# 281     corroborate
# 371          debunk
# 616         gainsay
# 716    substantiate
# Name: Words, dtype: object
#
# Cluster119:
# 265    languid
# 806    pensive
# Name: Words, dtype: object
#
# Cluster120:
# 266    mollify
# 548    appease
# Name: Words, dtype: object
#
# Cluster121:
# 267    pretentious
# 668      bombastic
# Name: Words, dtype: object
#
# Cluster122:
# 268       duress
# 761    coercion
# Name: Words, dtype: object
#
# Cluster123:
# 272    nonplussed
# 323     flummoxed
# 791     befuddled
# Name: Words, dtype: object
#
# Cluster124:
# 274        decry
# 350     denounce
# 458     admonish
# 754    repudiate
# Name: Words, dtype: object
#
# Cluster125:
# 275     recourse
# 652    equitable
# Name: Words, dtype: object
#
# Cluster126:
# 277    neutralize
# 623       nullify
# Name: Words, dtype: object
#
# Cluster127:
# 281     corroborate
# 371          debunk
# 616         gainsay
# 716    substantiate
# Name: Words, dtype: object
#
# Cluster128:
# 282        disparate
# 379    heterogeneous
# 405        divergent
# Name: Words, dtype: object
#
# Cluster129:
# 285    ephemeral
# 389      prosaic
# 621      mundane
# Name: Words, dtype: object
#
# Cluster130:
# 290    intimate
# 319     discreet
# Name: Words, dtype: object
#
# Cluster131:
# 292     mitigate
# 615    forestall
# 624      obviate
# Name: Words, dtype: object
#
# Cluster132:
# 295    paradigmatic
# 735       dichotomy
# 789      antithesis
# Name: Words, dtype: object
#
# Cluster133:
# 296    pedantic
# 663      prolix
# Name: Words, dtype: object
#
# Cluster134:
# 302        prudent
# 690          chary
# 730    circumspect
# Name: Words, dtype: object
#
# Cluster135:
# 303    punctilious
# 654    industrious
# 797     fastidious
# Name: Words, dtype: object
#
# Cluster136:
# 305    scrupulous
# 415     judicious
# Name: Words, dtype: object
#
# Cluster137:
# 306    tranquil
# 528      serene
# Name: Words, dtype: object
#
# Cluster138:
# 308    acquiesce
# 400      apropos
# Name: Words, dtype: object
#
# Cluster139:
# 311    animus
# 497    fester
# 715    enmity
# Name: Words, dtype: object
#
# Cluster140:
# 312    apologist
# 758      acolyte
# Name: Words, dtype: object
#
# Cluster141:
# 317         deride
# 356         berate
# 361        subsume
# 386    marginalize
# 393     stigmatize
# 439       harangue
# 503        lionize
# 563         malign
# 593         impugn
# 606        upbraid
# 669       lambaste
# 680      excoriate
# 726     deprecate
# 795      exculpate
# Name: Words, dtype: object
#
# Cluster142:
# 320     divorced
# 375    estranged
# Name: Words, dtype: object
#
# Cluster143:
# 321    elitist
# 558    insular
# Name: Words, dtype: object
#
# Cluster144:
# 322    exacting
# 453       rigor
# Name: Words, dtype: object
#
# Cluster145:
# 323    flummoxed
# 791    befuddled
# Name: Words, dtype: object
#
# Cluster146:
# 333    torpor
# 399    apathy
# Name: Words, dtype: object
#
# Cluster147:
# 334    trenchant
# 568    prescient
# Name: Words, dtype: object
#
# Cluster148:
# 335    umbrage
# 664      scorn
# 700    disdain
# Name: Words, dtype: object
#
# Cluster149:
# 340    assail
# 759    anoint
# Name: Words, dtype: object
#
# Cluster150:
# 347    plaintive
# 678        dirge
# Name: Words, dtype: object
#
# Cluster151:
# 350     denounce
# 458     admonish
# 754    repudiate
# Name: Words, dtype: object
#
# Cluster152:
# 354      benevolent
# 776      munificent
# 837    providential
# Name: Words, dtype: object
#
# Cluster153:
# 356         berate
# 361        subsume
# 386    marginalize
# 393     stigmatize
# 439       harangue
# 503        lionize
# 563         malign
# 593         impugn
# 606        upbraid
# 669       lambaste
# 680      excoriate
# 726     deprecate
# 795      exculpate
# Name: Words, dtype: object
#
# Cluster154:
# 358    mercurial
# 653      erratic
# Name: Words, dtype: object
#
# Cluster155:
# 361        subsume
# 386    marginalize
# 393     stigmatize
# 439       harangue
# 503        lionize
# 563         malign
# 593         impugn
# 606        upbraid
# 669       lambaste
# 680      excoriate
# 726     deprecate
# 795      exculpate
# Name: Words, dtype: object
#
# Cluster156:
# 363    condone
# 638       abet
# Name: Words, dtype: object
#
# Cluster157:
# 365    jeopardize
# 394     undermine
# 479       subvert
# 546      supplant
# 670      undercut
# Name: Words, dtype: object
#
# Cluster158:
# 366    disinterested
# 368            aloof
# Name: Words, dtype: object
#
# Cluster159:
# 371          debunk
# 616         gainsay
# 716    substantiate
# Name: Words, dtype: object
#
# Cluster160:
# 376    extravagant
# 377       fanciful
# Name: Words, dtype: object
#
# Cluster161:
# 378    frivolous
# 697      exigent
# Name: Words, dtype: object
#
# Cluster162:
# 379    heterogeneous
# 405        divergent
# Name: Words, dtype: object
#
# Cluster163:
# 380       imperious
# 473    presumptuous
# 538        insolent
# 687         haughty
# 711        impudent
# Name: Words, dtype: object
#
# Cluster164:
# 381      impertinent
# 645           blithe
# 679    imperturbable
# 741       felicitous
# 769        facetious
# Name: Words, dtype: object
#
# Cluster165:
# 383    irresolute
# 480      timorous
# 512      skittish
# Name: Words, dtype: object
#
# Cluster166:
# 384       laudable
# 688      estimable
# 707    redoubtable
# Name: Words, dtype: object
#
# Cluster167:
# 386    marginalize
# 393     stigmatize
# 439       harangue
# 503        lionize
# 563         malign
# 593         impugn
# 606        upbraid
# 669       lambaste
# 680      excoriate
# 726     deprecate
# 795      exculpate
# Name: Words, dtype: object
#
# Cluster168:
# 388      plodding
# 452       tedious
# 504    monotonous
# Name: Words, dtype: object
#
# Cluster169:
# 389    prosaic
# 621    mundane
# Name: Words, dtype: object
#
# Cluster170:
# 393    stigmatize
# 439      harangue
# 503       lionize
# 563        malign
# 593        impugn
# 606       upbraid
# 669      lambaste
# 680     excoriate
# 726    deprecate
# 795     exculpate
# Name: Words, dtype: object
#
# Cluster171:
# 394    undermine
# 479      subvert
# 546     supplant
# 670     undercut
# Name: Words, dtype: object
#
# Cluster172:
# 397    zealous
# 539     ardent
# 836     pious
# Name: Words, dtype: object
#
# Cluster173:
# 404        distort
# 781    prevaricate
# Name: Words, dtype: object
#
# Cluster174:
# 412    forsake
# 414       heed
# 742    forbear
# Name: Words, dtype: object
#
# Cluster175:
# 414       heed
# 742    forbear
# Name: Words, dtype: object
#
# Cluster176:
# 418    propriety
# 474      probity
# Name: Words, dtype: object
#
# Cluster177:
# 424    unscrupulous
# 586    disingenuous
# 794         evasive
# 822     duplicitous
# Name: Words, dtype: object
#
# Cluster178:
# 432    delineate
# 494    elucidate
# Name: Words, dtype: object
#
# Cluster179:
# 437        relent
# 510    relinquish
# Name: Words, dtype: object
#
# Cluster180:
# 439      harangue
# 503       lionize
# 563        malign
# 593        impugn
# 606       upbraid
# 669      lambaste
# 680     excoriate
# 726    deprecate
# 795     exculpate
# Name: Words, dtype: object
#
# Cluster181:
# 445        whimsical
# 535         eclectic
# 537    idiosyncratic
# 753           quirky
# Name: Words, dtype: object
#
# Cluster182:
# 451         adept
# 662    proficient
# Name: Words, dtype: object
#
# Cluster183:
# 452       tedious
# 504    monotonous
# Name: Words, dtype: object
#
# Cluster184:
# 458     admonish
# 754    repudiate
# Name: Words, dtype: object
#
# Cluster185:
# 459      aesthetic
# 636    utilitarian
# Name: Words, dtype: object
#
# Cluster186:
# 460    affectation
# 554      hyperbole
# Name: Words, dtype: object
#
# Cluster187:
# 470    engender
# 717     agitate
# 737      elicit
# Name: Words, dtype: object
#
# Cluster188:
# 473    presumptuous
# 538        insolent
# 687         haughty
# 711        impudent
# Name: Words, dtype: object
#
# Cluster189:
# 476      specious
# 589    fallacious
# 723     sophistry
# Name: Words, dtype: object
#
# Cluster190:
# 477    spurious
# 581       bogus
# Name: Words, dtype: object
#
# Cluster191:
# 479     subvert
# 546    supplant
# 670    undercut
# Name: Words, dtype: object
#
# Cluster192:
# 480    timorous
# 512    skittish
# Name: Words, dtype: object
#
# Cluster193:
# 483    transient
# 501      inhibit
# Name: Words, dtype: object
#
# Cluster194:
# 485    underscore
# 608    accentuate
# Name: Words, dtype: object
#
# Cluster195:
# 486         venal
# 660    pernicious
# 691     repugnant
# Name: Words, dtype: object
#
# Cluster196:
# 493         curtail
# 583    circumscribe
# Name: Words, dtype: object
#
# Cluster197:
# 497    fester
# 715    enmity
# Name: Words, dtype: object
#
# Cluster198:
# 498    iconoclastic
# 630      pugnacious
# Name: Words, dtype: object
#
# Cluster199:
# 502    inscrutable
# 625    omnipresent
# Name: Words, dtype: object
#
# Cluster200:
# 503       lionize
# 563        malign
# 593        impugn
# 606       upbraid
# 669      lambaste
# 680     excoriate
# 726    deprecate
# 795     exculpate
# Name: Words, dtype: object
#
# Cluster201:
# 515      thorough
# 749    meticulous
# Name: Words, dtype: object
#
# Cluster202:
# 517    vociferous
# 551     clamorous
# Name: Words, dtype: object
#
# Cluster203:
# 518    lugubrious
# 673    peccadillo
# Name: Words, dtype: object
#
# Cluster204:
# 532       morose
# 557     indolent
# 813    somnolent
# Name: Words, dtype: object
#
# Cluster205:
# 535         eclectic
# 537    idiosyncratic
# 753           quirky
# Name: Words, dtype: object
#
# Cluster206:
# 537    idiosyncratic
# 753           quirky
# Name: Words, dtype: object
#
# Cluster207:
# 538    insolent
# 687     haughty
# 711    impudent
# Name: Words, dtype: object
#
# Cluster208:
# 539    ardent
# 836    pious
# Name: Words, dtype: object
#
# Cluster209:
# 540     doctrinaire
# 559    intransigent
# Name: Words, dtype: object
#
# Cluster210:
# 541     officious
# 804    nonchalant
# Name: Words, dtype: object
#
# Cluster211:
# 544     conducive
# 572    salubrious
# Name: Words, dtype: object
#
# Cluster212:
# 546    supplant
# 670    undercut
# Name: Words, dtype: object
#
# Cluster213:
# 555    immutable
# 770     fallible
# Name: Words, dtype: object
#
# Cluster214:
# 557     indolent
# 813    somnolent
# Name: Words, dtype: object
#
# Cluster215:
# 561    irreverent
# 600         pithy
# 738       erudite
# 750       mordant
# Name: Words, dtype: object
#
# Cluster216:
# 562    loathe
# 792    eschew
# Name: Words, dtype: object
#
# Cluster217:
# 563        malign
# 593        impugn
# 606       upbraid
# 669      lambaste
# 680     excoriate
# 726    deprecate
# 795     exculpate
# Name: Words, dtype: object
#
# Cluster218:
# 575    soporific
# 696        heady
# Name: Words, dtype: object
#
# Cluster219:
# 586     disingenuous
# 602    sanctimonious
# 794          evasive
# 822      duplicitous
# Name: Words, dtype: object
#
# Cluster220:
# 589    fallacious
# 723     sophistry
# Name: Words, dtype: object
#
# Cluster221:
# 591    hinder
# 745    impede
# 800    hamper
# Name: Words, dtype: object
#
# Cluster222:
# 593        impugn
# 606       upbraid
# 669      lambaste
# 680     excoriate
# 726    deprecate
# 795     exculpate
# Name: Words, dtype: object
#
# Cluster223:
# 597        miserly
# 640    acquisitive
# Name: Words, dtype: object
#
# Cluster224:
# 600      pithy
# 738    erudite
# 750    mordant
# Name: Words, dtype: object
#
# Cluster225:
# 602    sanctimonious
# 794          evasive
# Name: Words, dtype: object
#
# Cluster226:
# 606       upbraid
# 669      lambaste
# 680     excoriate
# 726    deprecate
# 795     exculpate
# Name: Words, dtype: object
#
# Cluster227:
# 614    flamboyant
# 768     ebullient
# Name: Words, dtype: object
#
# Cluster228:
# 615    forestall
# 624      obviate
# Name: Words, dtype: object
#
# Cluster229:
# 616         gainsay
# 716    substantiate
# Name: Words, dtype: object
#
# Cluster230:
# 631    sagacious
# 814        stoic
# Name: Words, dtype: object
#
# Cluster231:
# 637         vapid
# 744    hodgepodge
# Name: Words, dtype: object
#
# Cluster232:
# 642    attenuate
# 817         wane
# Name: Words, dtype: object
#
# Cluster233:
# 645           blithe
# 679    imperturbable
# 741       felicitous
# 769        facetious
# Name: Words, dtype: object
#
# Cluster234:
# 654    industrious
# 797     fastidious
# Name: Words, dtype: object
#
# Cluster235:
# 660    pernicious
# 691     repugnant
# Name: Words, dtype: object
#
# Cluster236:
# 661    predicament
# 714       quandary
# Name: Words, dtype: object
#
# Cluster237:
# 664      scorn
# 700    disdain
# Name: Words, dtype: object
#
# Cluster238:
# 669      lambaste
# 680     excoriate
# 726    deprecate
# 795     exculpate
# Name: Words, dtype: object
#
# Cluster239:
# 679    imperturbable
# 741       felicitous
# 769        facetious
# Name: Words, dtype: object
#
# Cluster240:
# 680     excoriate
# 726    deprecate
# 795     exculpate
# Name: Words, dtype: object
#
# Cluster241:
# 681    curmudgeon
# 747     irascible
# Name: Words, dtype: object
#
# Cluster242:
# 686    implacable
# 713          wily
# 748     mercenary
# 763       cunning
# Name: Words, dtype: object
#
# Cluster243:
# 687     haughty
# 711    impudent
# Name: Words, dtype: object
#
# Cluster244:
# 688      estimable
# 707    redoubtable
# Name: Words, dtype: object
#
# Cluster245:
# 690          chary
# 730    circumspect
# Name: Words, dtype: object
#
# Cluster246:
# 713         wily
# 748    mercenary
# 763      cunning
# Name: Words, dtype: object
#
# Cluster247:
# 717    agitate
# 737     elicit
# Name: Words, dtype: object
#
# Cluster248:
# 726    deprecate
# 795     exculpate
# Name: Words, dtype: object
#
# Cluster249:
# 735     dichotomy
# 789    antithesis
# Name: Words, dtype: object
#
# Cluster250:
# 738    erudite
# 750    mordant
# Name: Words, dtype: object
#
# Cluster251:
# 741    felicitous
# 769     facetious
# Name: Words, dtype: object
#
# Cluster252:
# 743    haphazard
# 757    turbulent
# Name: Words, dtype: object
#
# Cluster253:
# 745    impede
# 800    hamper
# Name: Words, dtype: object
#
# Cluster254:
# 748    mercenary
# 763      cunning
# Name: Words, dtype: object
#
# Cluster255:
# 756      trifling
# 786    transitory
# Name: Words, dtype: object
#
# Cluster256:
# 764    discomfit
# 773     inveigle
# Name: Words, dtype: object
#
# Cluster257:
# 776      munificent
# 837    providential
# Name: Words, dtype: object
#
# Cluster258:
# 788     acumen
# 838    prowess
# Name: Words, dtype: object
#
# Cluster259:
# 794        evasive
# 822    duplicitous
# Name: Words, dtype: object

# %%
clust={}
good_clusters=[28,33,38,39,41,23,17,16,14,12,8,6,2,1,46,53,55,61,65,67,74,76,88,89,90,91,93,119,223,189,190,155]
axes=plt.axes()
for i in good_clusters:
    syn=plot_idx[i-1]
    vis=visualize_words[syn,:]
    axes.scatter(vis[:,0],vis[:,1])
    axes.annotate(gre_words['Words'][syn[0]],vis[0])
    #print("Cluster "+str(i)+":")
    clust[gre_words['Words'][syn[0]]]=list(gre_words["Words"][syn])
    #print(list(gre_words["Words"][syn]))
max_len=0
for x,y in clust.items():
    if len(y)>max_len:
        max_len=len(y)
for x,y in clust.items():
    if len(y)<max_len:
        for i in range(max_len-len(y)):
            y.append("")

ax = plt.subplot(111, frame_on=False) # no visible frame
ax.xaxis.set_visible(False)  # hide the x axis
ax.yaxis.set_visible(False)  # hide the y axis

table(ax, pd.DataFrame(clust)[1:].transpose())  # where df is your data frame

plt.savefig('mytable.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ea1ca9486334> in <module>
#       1 clust={}
#       2 good_clusters=[28,33,38,39,41,23,17,16,14,12,8,6,2,1,46,53,55,61,65,67,74,76,88,89,90,91,93,119,223,189,190,155]
# ----> 3 axes=plt.axes()
#       4 for i in good_clusters:
#       5     syn=plot_idx[i-1]
#
# NameError: name 'plt' is not defined
